# %% [markdown]
# # Sample Merge Utility
#
# **Usage:**
# - Input: A sample layout text file specifying sample IDs in a grid (rows and columns).
# - Data location: Directory containing all .h5ad files, each named after the sample IDs in the layout.
# - Use a dash '-' in the layout file to indicate missing samples in a given row or column.
#
# This notebook merges spatial transcriptomics samples according to the provided layout, ensuring all .h5ad files are present in the specified data directory.

# %%
import importlib
import sample_merge
importlib.reload(sample_merge)
from sample_merge import sample_merge

data_location = "/path/to/your/all h5ad data/"  # Update this to your actual data location

merged_adata = sample_merge(
    layout_file="Sample_layout_input.txt",
    data_location=data_location,
    output_file="merged_adata.h5ad",
    horizontal_spacing_multiplier=1.5,
    vertical_spacing_multiplier=1.5,
)
